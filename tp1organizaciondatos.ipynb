# %%
# magic function para hacer que los graficos de matplotlib se renderizen en el notebook.
# %matplotlib inline

import datetime as datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('default') # haciendo los graficos un poco mas bonitos xD
plt.rcParams['figure.figsize'] = (15, 5)

# %%
#relacion_cantidad_departamentos_con_precio_zona_en_capital
#mayor cantidad de precios promedio por estados en capital federal
#ayor cantidad de precios promedio  capital federal y cba
#Relacion del precio promedio por estado cantidad de departamentos en capital y cba
#cantidad de publicaciones de ventas,durante el 2012 a 2017 en todo capita y cba
 #cantidad de publicaciones de ventas,durante el 2012 a 2017 solo en Capital federal 
    #cantidad de publicaciones de ventas,durante el 2012 a 2017 solo en "Bs.As. G.B.A. Zona Sur"
    #cantidad de superficie cubierta de la empresa properati en capital federal,Bs.As. G.B.A. Zona Norte,Bs.As. G.B.A. Zona Oeste

# %%
prop_vent = pd.read_csv('../data/tp1orga/propsell.csv', low_memory=False)

# %%
 prop_vent.head()
# Out:
#                                          id  created_on operation  \
# 0  c8a66ee9e3da083ab66dacd165e8a5cc718b1cf2  2012-09-19      sell
# 1  a205c53378e7879cf7519659317fb410c060d20e  2012-10-22      sell
# 2  e06d6f864a0b91346594da4d27ceddcef0947ea6  2012-11-01      sell
# 3  a07927207d2a03de5f4ba7fd76f670d6285a3315  2012-11-26      sell
# 4  9446052c949050359fb08b9f1ba83ba2eaa20c99  2012-12-08      sell
#
#   property_type            place_name  \
# 0         house  San Antonio De Padua
# 1         house  San Antonio De Padua
# 2     apartment         Mar del Plata
# 3         house  Sierra de los Padres
# 4         house             Mataderos
#
#                              place_with_parent_names country_name  \
# 0  |Argentina|Bs.As. G.B.A. Zona Oeste|Merlo|San ...    Argentina
# 1  |Argentina|Bs.As. G.B.A. Zona Oeste|Merlo|San ...    Argentina
# 2  |Argentina|Buenos Aires Costa Atlántica|Mar de...    Argentina
# ...

# %%
prop_vent.tail()
# Out:
#                                               id  created_on operation  \
# 187477  91b7a3a73c3d869babaf11a446fad1fd967bc35d  2017-08-01      sell
# 187478  aba0d7d6f6f87365d97a4f7bc133f3ef59a70a20  2017-08-01      sell
# 187479  e935e6dca58a5b2fec2101f8c7ac1494722119a6  2017-08-01      sell
# 187480  d236e3424ac94ab9fcd5d2c22aed59eeed695adc  2017-08-01      sell
# 187481  9439664d30d10181efbae84ed01e6d991087deed  2017-08-01      sell
#
#        property_type               place_name  \
# 187477         house                  Rosario
# 187478         house                 Belgrano
# 187479         house                 Martínez
# 187480     apartment               Villa Luro
# 187481         house  San Carlos de Bariloche
#
#                                   place_with_parent_names country_name  \
# 187477                       |Argentina|Santa Fe|Rosario|    Argentina
# 187478               |Argentina|Capital Federal|Belgrano|    Argentina
# ...

# %%
prop_vent.columns.values
# Out:
# array(['id', 'created_on', 'operation', 'property_type', 'place_name',
#        'place_with_parent_names', 'country_name', 'state_name',
#        'geonames_id', 'lat-lon', 'lat', 'lon', 'price', 'currency',
#        'price_aprox_local_currency', 'price_aprox_usd',
#        'surface_total_in_m2', 'surface_covered_in_m2', 'price_usd_per_m2',
#        'price_per_m2', 'floor', 'rooms', 'expenses', 'properati_url',
#        'description', 'title', 'image_thumbnail'], dtype=object)

# %%
prop_vent.isnull().sum()
# Out:
# id                                 0
# created_on                         0
# operation                          0
# property_type                      0
# place_name                        35
# place_with_parent_names            0
# country_name                       0
# state_name                         0
# geonames_id                    29164
# lat-lon                        68721
# lat                            68721
# lon                            68721
# price                          33039
# currency                       33041
# price_aprox_local_currency     33039
# price_aprox_usd                33039
# surface_total_in_m2            62455
# surface_covered_in_m2          35062
# price_usd_per_m2               82458
# price_per_m2                   55817
# floor                         173188
# rooms                         107162
# expenses                      169962
# properati_url                      0
# description                        9
# ...

# %%
prop_vent.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187482 entries, 0 to 187481
# Data columns (total 27 columns):
# id                            187482 non-null object
# created_on                    187482 non-null object
# operation                     187482 non-null object
# property_type                 187482 non-null object
# place_name                    187447 non-null object
# place_with_parent_names       187482 non-null object
# country_name                  187482 non-null object
# state_name                    187482 non-null object
# geonames_id                   158318 non-null float64
# lat-lon                       118761 non-null object
# lat                           118761 non-null float64
# lon                           118761 non-null float64
# price                         154443 non-null float64
# currency                      154441 non-null object
# price_aprox_local_currency    154443 non-null float64
# ...

# %%
prop_vent.describe()
# Out:
#         geonames_id            lat            lon         price  \
# count  1.583180e+05  118761.000000  118761.000000  1.544430e+05
# mean   3.560821e+06     -34.775631     -59.207578  4.402848e+05
# std    3.442029e+05       2.071562       2.293300  1.915257e+06
# min    3.427208e+06     -54.833014     -75.678931  0.000000e+00
# 25%    3.430116e+06     -34.729040     -58.718531  1.050000e+05
# 50%    3.433359e+06     -34.604154     -58.483665  1.800000e+05
# 75%    3.832260e+06     -34.457223     -58.383317  3.950000e+05
# max    6.948895e+06       4.545843     -40.149218  6.500000e+08
#
#        price_aprox_local_currency  price_aprox_usd  surface_total_in_m2  \
# count                1.544430e+05     1.544430e+05        125027.000000
# mean                 4.298946e+06     2.436423e+05           297.023707
# std                  6.870371e+06     3.893775e+05          2072.795972
# min                  0.000000e+00     0.000000e+00             0.000000
# ...

# %%
 prop_vent[['surface_total_in_m2','price_per_m2']][:5]
# Out:
#    surface_total_in_m2  price_per_m2
# 0                333.0   1290.322581
# 1                220.0   1000.000000
# 2                  NaN           NaN
# 3                661.0           NaN
# 4                300.0   1796.116505

# %%
prop_vent[['price']].isnull() #vemos que hay muchos que no tienen precio
# Out:
#         price
# 0       False
# 1       False
# 2        True
# 3        True
# 4       False
# 5       False
# 6       False
# 7        True
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14       True
# 15       True
# 16      False
# 17      False
# 18       True
# 19       True
# 20      False
# 21      False
# 22      False
# 23      False
# 24       True
# 25       True
# 26       True
# 27       True
# 28       True
# 29      False
# ...       ...
# 187452   True
# 187453   True
# 187454   True
# 187455   True
# 187456   True
# 187457   True
# 187458   True
# 187459   True
# 187460   True
# 187461   True
# 187462   True
# 187463   True
# 187464   True
# 187465  False
# 187466  False
# 187467  False
# 187468  False
# 187469  False
# 187470  False
# 187471  False
# 187472  False
# 187473  False
# 187474  False
# 187475  False
# 187476  False
# 187477   True
# 187478  False
# 187479  False
# 187480  False
# 187481   True
#
# ...

# %%
prop_vent[['price']].isnull().sum() #cantidad_exacta
# Out:
# price    33039
# dtype: int64

# %%
a=prop_vent[prop_vent['price'].isnull()]  #filtro por plos que no tiene precio

# %%
b=a[a['surface_total_in_m2'].isnull()|a['price_per_m2'].isnull()]# como

# %%
fig = plt.figure(figsize=(10,4));
prop_vent['price'].value_counts()
# Out:
# 120000.0     2817
# 130000.0     2324
# 110000.0     2239
# 85000.0      2238
# 150000.0     2234
# 75000.0      2096
# 140000.0     2049
# 250000.0     2002
# 160000.0     1917
# 90000.0      1888
# 95000.0      1831
# 180000.0     1768
# 125000.0     1768
# 80000.0      1749
# 220000.0     1657
# 135000.0     1589
# 65000.0      1589
# 100000.0     1544
# 350000.0     1543
# 115000.0     1501
# 170000.0     1407
# 70000.0      1382
# 200000.0     1308
# 230000.0     1287
# 240000.0     1254
# 60000.0      1207
# 145000.0     1201
# 165000.0     1178
# 190000.0     1153
# 105000.0     1127
#              ...
# 631280.0        1
# 2525000.0       1
# 315623.0        1
# 1262471.0       1
# 2522650.0       1
# 78833.0         1
# 111602.0        1
# 157669.0        1
# 9300.0          1
# 94348.0         1
# 2523000.0       1
# 1261564.0       1
# 62400.0         1
# 446498.0        1
# 1056000.0       1
# 157719.0        1
# 1261800.0       1
# 3019000.0       1
# 254223.0        1
# ...

# %%
#Al ser un barrio mas caro entonces es mayor la cantidad de departsmentos que de casas?

# %%
prop_vent['state_name'].value_counts()
# Out:
# Capital Federal                 44152
# Bs.As. G.B.A. Zona Norte        39888
# Bs.As. G.B.A. Zona Oeste        22571
# Buenos Aires Costa Atlántica    20694
# Bs.As. G.B.A. Zona Sur          18135
# Córdoba                         15777
# Santa Fe                        13516
# Buenos Aires Interior            4686
# Río Negro                        1152
# Neuquén                          1057
# Mendoza                           927
# Misiones                          817
# Entre Ríos                        793
# Tucumán                           715
# Corrientes                        629
# San Luis                          444
# Salta                             372
# Chubut                            329
# La Pampa                          301
# Catamarca                         126
# Chaco                              95
# San Juan                           86
# Tierra Del Fuego                   69
# Formosa                            66
# Santa Cruz                         40
# ...

# %%
#zona analizar
capital=prop_vent['state_name']=="Capital Federal"
gbazn=prop_vent['state_name']=="Bs.As. G.B.A. Zona Norte"
gbazo=prop_vent['state_name']=="Bs.As. G.B.A. Zona Oeste"
gbazs=prop_vent['state_name']=="Bs.As. G.B.A. Zona Sur"

archivofiltrado=prop_vent[capital|gbazn|gbazo|gbazs]

# %%
 archivofiltrado[['state_name','price']].groupby('state_name').agg({'price':'mean'}).sort_values( by='price' ,ascending=False)
# Out:
#                                   price
# state_name
# Bs.As. G.B.A. Zona Norte  440041.444071
# Capital Federal           399379.215122
# Bs.As. G.B.A. Zona Sur    243089.246005
# Bs.As. G.B.A. Zona Oeste  187604.998996

# %%
 top_con_mayor_promedio_precio_CapitalFederal=archivofiltrado[['state_name','place_name','price']][archivofiltrado['state_name']=="Capital Federal"].groupby('place_name').agg({'price':'mean'}).sort_values( by='price' ,ascending=False)
top_con_mayor_promedio_precio_CapitalFederal.head()
# Out:
#                       price
# place_name
# Palermo Chico  1.084513e+06
# Puerto Madero  9.522133e+05
# Retiro         7.703451e+05
# Nuñez          7.053039e+05
# Belgrano       6.985532e+05

# %%
x=archivofiltrado['state_name']=="Capital Federal"
y=archivofiltrado['property_type']=="apartment"
z=archivofiltrado['surface_covered_in_m2']==47.000000

# %%
 relacion_cantidad_departamentos_con_precio_zona_en_capital=top_con_mayor_promedio_precio_GB=archivofiltrado[['state_name','place_name','price','property_type']][ x& y].groupby('place_name').agg({'price':'mean','property_type':'count'}).sort_values( by='price' ,ascending=False)
relacion_cantidad_departamentos_con_precio_zona_en_capital.head()
# Out:
#                        price  property_type
# place_name
# Puerto Madero  937521.570577           1119
# Palermo Chico  884023.148760            285
# Retiro         747556.532680            335
# Belgrano       690193.982280           3458
# San Telmo      613801.791227           1291

# %%
relacion_cantidad_departamentos_con_precio_zona_en_capital.rename(columns={'property_type': 'Cantidad De Departamentos'}, inplace=True)
relacion_cantidad_departamentos_con_precio_zona_en_capital.head()
# Out:
#                        price  Cantidad De Departamentos
# place_name
# Puerto Madero  937521.570577                       1119
# Palermo Chico  884023.148760                        285
# Retiro         747556.532680                        335
# Belgrano       690193.982280                       3458
# San Telmo      613801.791227                       1291

# %%
relacion_cantidad_departamentos_con_precio_zona_en_capital.plot.bar(x='Cantidad De Departamentos',y='price',label='Relacion del precio promedio por estado cantidad de departamentos')

# %%
top_con_mayor_promedio_precio_GB=archivofiltrado[['state_name','place_name','price']][archivofiltrado['state_name']!="Capital Federal"].groupby('place_name').agg({'price':'mean'}).sort_values( by='price' ,ascending=False)

top_con_mayor_promedio_precio_GB.head()
# Out:
#                          price
# place_name
# Barrio La Isla    1.863260e+06
# Bahía del Sol     1.575000e+06
# San Isidro Chico  1.508000e+06
# The Boating Club  1.200000e+06
# Gutierrez         1.180000e+06

# %%
#tipo de propiedades que hay
archivofiltrado['property_type'].value_counts()
# Out:
# apartment    68826
# house        44258
# PH            7045
# store         4617
# Name: property_type, dtype: int64

# %%
 departamentos=archivofiltrado[['state_name','place_name','property_type']][archivofiltrado['property_type']=="apartment"]
departamentos.head()
# Out:
#                   state_name       place_name property_type
# 5   Bs.As. G.B.A. Zona Norte            Pilar     apartment
# 10  Bs.As. G.B.A. Zona Norte            Pilar     apartment
# 13  Bs.As. G.B.A. Zona Norte          Florida     apartment
# 29  Bs.As. G.B.A. Zona Oeste      Ramos Mejía     apartment
# 31  Bs.As. G.B.A. Zona Oeste  Villa Luzuriaga     apartment

# %%
#cantidad de departamentos
departamentos['property_type'].count()
# Out:
# 68826

# %%
departamentoscasas=archivofiltrado[['state_name','place_name','property_type']][archivofiltrado['property_type']=="house"]
departamentoscasas.head()
# Out:
#                   state_name            place_name property_type
# 0   Bs.As. G.B.A. Zona Oeste  San Antonio De Padua         house
# 1   Bs.As. G.B.A. Zona Oeste  San Antonio De Padua         house
# 4            Capital Federal             Mataderos         house
# 12  Bs.As. G.B.A. Zona Norte             Benavidez         house
# 28  Bs.As. G.B.A. Zona Oeste                 Haedo         house

# %%
departamentoscasas['property_type'].count()
# Out:
# 44258

# %%
departamentoscasas=archivofiltrado[['state_name','place_name','property_type']].groupby('property_type').agg({'property_type':'count'})
departamentoscasas
# Out:
#                property_type
# property_type
# PH                      7045
# apartment              68826
# house                  44258
# store                   4617

# %%
departamentoscasas.rename(columns={'property_type': 'AIRLINE_CODE','AIRLINE_y': 'AIRLINE'}, inplace=True)

# %%
top_con_mayor_promedio_precio_GB=archivofiltrado[['state_name','place_name','price','property_type']][archivofiltrado['state_name']!="Capital Federal"].groupby(['place_name','property_type']).agg({'price':'mean','property_type':'count'}).sort_values( by='price' ,ascending=False)

top_con_mayor_promedio_precio_GB.head()
# Out:
#                                         price  property_type
# place_name        property_type
# Llavallol         store          9.421364e+06             12
# General Rodríguez PH             3.910581e+06              4
# Belén de Escobar  store          2.938500e+06              2
# Cuartel V         store          2.100000e+06              1
# Barrio La Isla    house          2.002917e+06             13

# %%
#####
#Evolucion del precio de la propiedad a travez zel ano 2012 a 2017 en una determinada zona

####

# %%
a=prop_vent['created_on']  
dates=[]

for  value in a.values:
    split= value.split(" ")
    aammdd=split[0].split("-")
    dates.append(aammdd)
    counter=0
    for index,row in prop_vent.iterrows():
        year=dates[counter][2]
        month=dates[counter][0]
        day=dates[counter][1]
        prop_vent.at[index,"years"]=int(year)
        prop_vent.at[index,"month"]=int(month)
        prop_vent.at[index,"day"]=int(day)
        counter+=1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-36-8a76dd81e5d3> in <module>()
#       8     counter=0
#       9     for index,row in prop_vent.iterrows():
# ---> 10         year=dates[counter][2]
#      11         month=dates[counter][0]
#      12         day=dates[counter][1]
#
# IndexError: list index out of range

# %%
prop_fecha=prop_vent['created_on'].str.split(' ',3,expand=True) 
a=prop_fecha[0].str.split('-',3,expand=True)
a
# Out:
#            0   1   2
# 0       2012  09  19
# 1       2012  10  22
# 2       2012  11  01
# 3       2012  11  26
# 4       2012  12  08
# 5       2013  01  04
# 6       2013  01  09
# 7       2013  01  12
# 8       2013  01  21
# 9       2013  01  21
# 10      2013  01  26
# 11      2013  01  31
# 12      2013  02  08
# 13      2013  02  15
# 14      2013  03  05
# 15      2013  03  05
# 16      2013  03  05
# 17      2013  03  05
# 18      2013  03  06
# 19      2013  03  07
# 20      2013  03  07
# 21      2013  03  07
# 22      2013  03  07
# 23      2013  03  09
# 24      2013  03  09
# 25      2013  03  11
# 26      2013  03  12
# 27      2013  03  15
# 28      2013  03  23
# 29      2013  03  23
# ...      ...  ..  ..
# 187452  2017  08  01
# 187453  2017  08  01
# 187454  2017  08  01
# 187455  2017  08  01
# 187456  2017  08  01
# 187457  2017  08  01
# 187458  2017  08  01
# 187459  2017  08  01
# 187460  2017  08  01
# 187461  2017  08  01
# 187462  2017  08  01
# ...

# %%
 prop_vent['year']=a[0]
prop_vent['month']=a[1]
prop_vent['day']=a[2]
prop_vent.head()
# Out:
#                                          id  created_on operation  \
# 0  c8a66ee9e3da083ab66dacd165e8a5cc718b1cf2  2012-09-19      sell
# 1  a205c53378e7879cf7519659317fb410c060d20e  2012-10-22      sell
# 2  e06d6f864a0b91346594da4d27ceddcef0947ea6  2012-11-01      sell
# 3  a07927207d2a03de5f4ba7fd76f670d6285a3315  2012-11-26      sell
# 4  9446052c949050359fb08b9f1ba83ba2eaa20c99  2012-12-08      sell
#
#   property_type            place_name  \
# 0         house  San Antonio De Padua
# 1         house  San Antonio De Padua
# 2     apartment         Mar del Plata
# 3         house  Sierra de los Padres
# 4         house             Mataderos
#
#                              place_with_parent_names country_name  \
# 0  |Argentina|Bs.As. G.B.A. Zona Oeste|Merlo|San ...    Argentina
# 1  |Argentina|Bs.As. G.B.A. Zona Oeste|Merlo|San ...    Argentina
# 2  |Argentina|Buenos Aires Costa Atlántica|Mar de...    Argentina
# ...

# %%
#cantidad de publicaciones de ventas,durante el 2012 a 2017
c=prop_vent.groupby('year').agg({'year':'count'})
c.plot()

# %%
 #cantidad de publicaciones de ventas,durante el 2012 a 2017 solo en Capital federal
x=prop_vent['state_name']=="Capital Federal"
c=prop_vent[['year','state_name']][x].groupby('year').agg({'year':'count'})
 c.plot()

# %%
 #cantidad de publicaciones de ventas,durante el 2012 a 2017 solo en "Bs.As. G.B.A. Zona Sur"
gbazs=prop_vent['state_name']=="Bs.As. G.B.A. Zona Sur"
 
c=prop_vent[['year','state_name']][gbazs].groupby('year').agg({'year':'count'})
 c.plot()

# %%
#cantidad de superficie cubierta de la empresa properati en capital federal,Bs.As. G.B.A. Zona Norte,Bs.As. G.B.A. Zona Oeste

archivofiltrado[['surface_covered_in_m2','state_name']].groupby('state_name').agg({'surface_covered_in_m2':'sum'}).plot()
